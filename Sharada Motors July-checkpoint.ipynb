# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib.colors import LinearSegmentedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.patheffects import PathPatchEffect, SimpleLineShadow, Normal

# %%
df = pd.read_excel("Sharada Monthly report-July-23.xlsx")

# %%
fig, ax = plt.subplots(figsize=(12, 5))
plt.plot(df['Date'], df['Inv 1'], linestyle='solid', color='#bce4d8', linewidth=1, label='Inv 1', zorder=2)
plt.plot(df['Date'], df['Inv 2'], linestyle='solid', color='#2c5985', linewidth=1, label='Inv 2', zorder=1)

# Add shadows by plotting lines with reduced opacity and slight offsets
plt.plot(df['Date'], df['Inv 1'], linestyle='solid', color='#bce4d8', linewidth=5, alpha=0.5, zorder=0)
plt.plot(df['Date'], df['Inv 2'], linestyle='solid', color='#2c5985', linewidth=5, alpha=0.5, zorder=0)

plt.xlabel('Date')
plt.ylabel('Specific Yield')
plt.title('Inverters Performance')
ax.set_xticks(df['Date'].dt.date)
ax.set_xticklabels(df['Date'].dt.strftime('%d'), rotation=30)

# Add a legend
plt.legend(loc='best')

plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['Cycle 1 Adherence', 'Cycle 2 Adherence', 'Cycle 3 Adherence']
sizes = [100, 100, 100]
colors = ['#e15759', '#f28e2b', '#4e79a7']
fig, ax = plt.subplots(figsize=(6, 6))

def autopct_format(pct):
    # Calculate the total size of all segments
    total = sum(sizes)
    # Calculate the size of the current segment as an integer
    val = int(round(pct * total / 100.0))
    return f'{val}'+'%'

# Plot the pie chart
ax.pie(sizes, labels=None, colors=colors, startangle=90, autopct=autopct_format)

# Add labels as a legend
ax.legend(labels, loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Clearance Adherence (%)')


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

Specific_Yield = df['Sp Yield']
dates = df['Date'].dt.strftime('%d')

# Define your x and y values
x = dates
y = Specific_Yield  # Replace with your actual y-values

# Define a custom colormap with the specified colors
colors = ['#d64d44', '#fbb656', '#32834a']
cmap = LinearSegmentedColormap.from_list('custom', colors, N=256)
norm = plt.Normalize(1, 4)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 5))

# Plot the line in segments with different colors based on y-value range
for i in range(len(x) - 1):
    x_segment = [x[i], x[i + 1]]
    y_segment = [y[i], y[i + 1]]
    color = cmap(norm(np.mean(y_segment)))
    ax.plot(x_segment, y_segment, color=color, linewidth=2)

# Create a color bar legend
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # You need this line for the colorbar to work properly
cbar = plt.colorbar(sm, ax=ax, label='Sp.Yield-Value Range')

# Set the color bar ticks and labels
cbar.set_ticks([1.5, 2.5, 3.5])  # Set the ticks in the middle of each y-value range
cbar.set_ticklabels(['1-2', '2-3', '3-4'])

# Set labels and title
plt.xlabel('Date')
plt.ylabel('Specific Yield')
plt.title('July Month Specific yield')

# Show the plot
plt.show()

# %%
labels = ['Inverter Unidentified Fault (mins)', 'Grid Fail (mins)']
colors = ['#2a5783', '#b9ddf1']
sizes = [165, 30]
explode = (0.1, 0)

plt.figure(figsize=(6, 6))

def my_autopct(pct):
    total = sum(sizes)
    val = int(round(pct*total/100.0))
    return f'{val} mins'

plt.pie(sizes,explode=explode, labels=labels, colors=colors, autopct=my_autopct, startangle=90)

plt.title('Downtime (mins)')

plt.show()

# %%
Act_Gen = [8949.7, 10683.4, 10385.2, 11031.8, 11173.5, 8928.3, 5617.5]
Estimate_Gen = [9681, 9535, 11048, 10525, 10185, 7437, 6189]
Year = ['Jan-23','Feb-23','Mar-23','Apr-23','May-23','Jun-23','July-23']

fig, ax1 = plt.subplots(figsize=(12, 5))

ax1.bar(x=Year, height=Act_Gen, width=0.35, align='center', color='#2c5985')
ax1.set_xlabel('Year')
ax1.set_ylabel('Act.Gen.2023(MWh)', color='black')
ax1.tick_params(axis='y', labelcolor='#2c5985')

ax2 = ax1.twinx()
ax2.bar(x=Year, height=Estimate_Gen, width=0.35 / 2, align='center', color='#bce4d8')
ax2.set_ylabel('Est.Gen.2023(MWh)', color='black')
ax2.tick_params(axis='y', labelcolor='#bce4d8')
plt.title('Month-wiseGen.(MWh)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
Act_Gen = [8949.7, 10683.4, 10385.2, 11031.8, 11173.5, 8928.3, 5617.5]
Estimate_Gen = [9681, 9535, 11048, 10525, 10185, 7437, 6189]
Year = ['Jan-23', 'Feb-23', 'Mar-23', 'Apr-23', 'May-23', 'Jun-23', 'July-23']

fig, ax1 = plt.subplots(figsize=(13, 6))

# Plot Actual Generation as bars with labels on top
ax1.bar(x=Year, height=Act_Gen, width=0.35, align='center', color='#2c5985', label='Actual Gen. 2023 (MWh)')
ax1.set_xlabel('Year')
ax1.set_ylabel('Act. Gen. 2023 (MWh)', color='black')
ax1.tick_params(axis='y', labelcolor='#2c5985')

ax2 = ax1.twinx()

# Plot Estimate Generation as bars with labels on the bars (rotated 90 degrees)
for i, est_gen in enumerate(Estimate_Gen):
    ax2.bar(x=Year[i], height=est_gen, width=0.35 / 2, align='center', color='#bce4d8', label='Est. Gen. 2023 (MWh)')
    ax1.text(i, Act_Gen[i], str(Act_Gen[i]), va='bottom', ha='center', rotation=0, color='#2c5985', fontsize=10)

ax2.set_ylabel('Est. Gen. 2023 (MWh)', color='black')
ax2.tick_params(axis='y', labelcolor='#bce4d8')

# Add legends for both sets of bars only once
ax1.legend(loc='upper left', frameon=False)
ax2.legend(loc='best', frameon=False)
#plt.legend(loc='best')

plt.title('Month-wise Gen. (MWh)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# Your data
dates = df['Date'].dt.strftime('%d')
expected_gen = df['Expected Gen.(kWh)']
actual_gen = df['Generation (kWh)']

#colors = ['red', '#ff7f0e', '#f8c75f','#007acc', '#2b7d45']
colors = ['#FF0000','#FFFF00','#FFD700','#00FF00','#0000FF']



cmap = LinearSegmentedColormap.from_list('custom', colors, N=256)

min_gen = actual_gen.min()
max_gen = actual_gen.max()
y_ranges = [
    (min_gen + i * (max_gen - min_gen) / 5, min_gen + (i + 1) * (max_gen - min_gen) / 5)
    for i in range(5)
]

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(15, 9))  # Increase the figure size

# Add a secondary y-axis on the right side for "Expected Generation"
ax2 = ax1.twinx()

ax1.set_title('July-23 Generation (kWh)')
ax1.set_xlabel('Date')

# Initialize color index for mapping
color_index = 0

# Plot the "Expected Generation" as a line plot on the secondary y-axis
ax2.plot(dates, expected_gen, color='blue', label='Expected Gen.(kWh)')

# Iterate over the data points and plot bars for "Generation" with colors based on y-value range
for date, act_gen in zip(dates, actual_gen):
    # Find the corresponding color based on the y-value range
    for i, (y_min, y_max) in enumerate(y_ranges):
        if y_min <= act_gen <= y_max:
            color_index = i
            break

    color = cmap(color_index / (len(y_ranges) - 1))  # Normalize color index

    ax1.bar(date, act_gen, color=color, alpha=0.5)  # Bars for actual generation

# Set labels and legends for both axes
ax1.set_ylabel('Actual Generation (kWh)')
ax2.set_ylabel('Expected Generation (kWh)')
ax1.legend(['Actual Gen.(kWh)'],bbox_to_anchor=(-0.01,-0.2),loc='upper left', frameon=False loc='upper left')  # Adjust legend position
ax2.legend(['Expected Gen.(kWh)'], loc='upper right')  # Adjust legend position



# Rotate x-axis labels
plt.xticks(rotation=30)

# Create a color bar legend outside the graph with custom tick locations and labels
sm = plt.cm.ScalarMappable(cmap=cmap)
sm.set_array([])  # You need this line for the colorbar to work properly

# Adjust the fraction parameter to move the color bar to the right
cbar = plt.colorbar(sm, ax=ax2, label='Actual Generation (kWh), Normalized',
                    ticks=[0, 1], fraction=0.060, pad=0.04)  # Adjust the fraction

# Set custom tick labels for the color bar
cbar.ax.set_yticklabels([min_gen, max_gen])

# Save the plot as a high-resolution PNG image
plt.tight_layout()
plt.savefig('output_plot.png', dpi=100)  # Specify DPI here
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

Act_Gen = [8949.7, 10683.4, 10385.2, 11031.8, 11173.5, 8928.3, 5617.5]
act_gen = [round(value, 2) for value in Act_Gen]

Estimate_Gen = [9681, 9535, 11048, 10525, 10185, 7437, 6189]

Year = ['Jan-23', 'Feb-23', 'Mar-23', 'Apr-23', 'May-23', 'Jun-23', 'July-23']
years = [date.replace('-', "'") for date in Year]

fig, ax1 = plt.subplots(figsize=(13, 6))

ax1.bar(x=years, height=act_gen, width=0.35, align='center', color='#2c5985', label='Actual Gen. 2023 (MWh)')
ax1.set_ylabel('Act. Gen. 2023 (MWh)', color='black')
ax1.tick_params(axis='y', labelcolor='#2c5985')

ax2 = ax1.twinx()

for i, est_gen in enumerate(Estimate_Gen):
    ax2.bar(x=years[i], height=est_gen, width=0.35 / 2, align='center', color='#bce4d8')
    ax2.text(i, act_gen[i] // 2, str(act_gen[i]), va='bottom', ha='center', rotation=90, color='black', fontsize=10)

legend_elements = [Patch(color='#bce4d8', label='Est. Gen. 2023 (MWh)')]
ax2.legend(handles=legend_elements, bbox_to_anchor=(0.98, -0.3), loc='lower right', frameon=False)

ax2.set_ylabel('Est. Gen. 2023 (MWh)', color='black')
ax2.tick_params(axis='y', labelcolor='#bce4d8')

ax1.legend(bbox_to_anchor=(-0.01, -0.3), loc='lower left', frameon=False)

plt.title('Month-wise Gen. (MWh)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Save the graph as a high-resolution image
plt.savefig('month-wise-gen.png', dpi=100)

plt.show()
